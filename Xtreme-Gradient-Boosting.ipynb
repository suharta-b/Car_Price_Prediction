# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np

# Importing the Xtreme Gradient Boosting Library
import xgboost as xgb

# Importing the libraries for Hyperparameter Tuning
from sklearn.model_selection import RandomizedSearchCV #-----Randomized Search CV

# Importing warnings for ignoring any warnings in the program
import warnings
warnings.filterwarnings("ignore")

# %%
# Loading dataset----Using pre-proceesd dataset---outliers not treated
car_xgb = pd.read_csv("Car_Preprocess.csv")
#----Random-Forest not sensitive towards outliers

# Viewing the dataset
car_xgb.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Years_Used  \
# 0           3.35           5.59       27000      0           6
# 1           4.75           9.54       43000      0           7
# 2           7.25           9.85        6900      0           3
# 3           2.85           4.15        5200      0           9
# 4           4.60           6.87       42450      0           6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
# Separating the independent and dependent features
X_data = car_xgb.iloc[:,1:]
y_data = car_xgb["Selling_Price"]

# Finding shape of independent and dependent variables
X_data.shape, y_data.shape
# Out:
# ((301, 8), (301,))

# %%
# Importing KFold cross-validation for splitting dataset 
from sklearn.model_selection import KFold

# Creating object of KFold
kf = KFold(n_splits = 5, shuffle = True, random_state = None) #----Performing 5-Fold cross-validation

# %%
# Splittting dataset into training and testing part using cross-validation
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data.iloc[train_index,:], X_data.iloc[test_index,:]
    y_train, y_test = y_data.iloc[train_index], y_data.iloc[test_index]

# Finding out the shape of training and testing set
X_train.shape, X_test.shape
y_train.shape, y_test.shape
# Out:
# ((241, 8), (60, 8))
# ((241,), (60,))

# %%
# Creating the object of Xtreme-Gradient-Boosting Regressor Class
xgb_reg = xgb.XGBRegressor()

# %%
# Creating parameter grid for hyper-parameter optimization
param_grid = {"n_estimators": [int(x) for x in np.linspace(start=100, stop=1200, num=12)],
             "learning_rate": ['0.05','0.1', '0.2','0.3','0.5','0.6'],
             "max_depth": [int(x) for x in np.linspace(5, 30, num=6)],
             "subsample": [0.7,0.6,0.8],
             "min_child_weigh": [3,4,5,6,7]}
#----Setting different values for various parameters of XGB Regressor

# Hyperparameter optimization using Randomized Search CV
random_search = RandomizedSearchCV(estimator=xgb_reg, param_distributions=param_grid, n_iter=10, n_jobs=1, cv=5, verbose=2)
#----Parameter grid being passed for performing hyperparameter optimization

# %%
# Fitting the model
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] subsample=0.7, n_estimators=400, min_child_weigh=5, max_depth=20, learning_rate=0.6
# [17:42:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=400, min_child_weigh=5, max_depth=20, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.7, n_estimators=400, min_child_weigh=5, max_depth=20, learning_rate=0.6
# [17:42:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=400, min_child_weigh=5, max_depth=20, learning_rate=0.6, total=   0.1s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] subsample=0.7, n_estimators=400, min_child_weigh=5, max_depth=20, learning_rate=0.6
# [17:42:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=400, min_child_weigh=5, max_depth=20, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.7, n_estimators=400, min_child_weigh=5, max_depth=20, learning_rate=0.6
# [17:42:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=400, min_child_weigh=5, max_depth=20, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.7, n_estimators=400, min_child_weigh=5, max_depth=20, learning_rate=0.6
# [17:42:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=400, min_child_weigh=5, max_depth=20, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.7, n_estimators=800, min_child_weigh=4, max_depth=10, learning_rate=0.6
# [17:42:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=800, min_child_weigh=4, max_depth=10, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.7, n_estimators=800, min_child_weigh=4, max_depth=10, learning_rate=0.6
# [17:42:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=800, min_child_weigh=4, max_depth=10, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.7, n_estimators=800, min_child_weigh=4, max_depth=10, learning_rate=0.6
# [17:42:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=800, min_child_weigh=4, max_depth=10, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.7, n_estimators=800, min_child_weigh=4, max_depth=10, learning_rate=0.6
# [17:42:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=800, min_child_weigh=4, max_depth=10, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.7, n_estimators=800, min_child_weigh=4, max_depth=10, learning_rate=0.6
# [17:42:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=800, min_child_weigh=4, max_depth=10, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.6, n_estimators=400, min_child_weigh=5, max_depth=5, learning_rate=0.5
# [17:42:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=400, min_child_weigh=5, max_depth=5, learning_rate=0.5, total=   0.1s
# [CV] subsample=0.6, n_estimators=400, min_child_weigh=5, max_depth=5, learning_rate=0.5
# [17:42:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=400, min_child_weigh=5, max_depth=5, learning_rate=0.5, total=   0.1s
# [CV] subsample=0.6, n_estimators=400, min_child_weigh=5, max_depth=5, learning_rate=0.5
# [17:42:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=400, min_child_weigh=5, max_depth=5, learning_rate=0.5, total=   0.1s
# [CV] subsample=0.6, n_estimators=400, min_child_weigh=5, max_depth=5, learning_rate=0.5
# [17:42:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=400, min_child_weigh=5, max_depth=5, learning_rate=0.5, total=   0.1s
# [CV] subsample=0.6, n_estimators=400, min_child_weigh=5, max_depth=5, learning_rate=0.5
# [17:42:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=400, min_child_weigh=5, max_depth=5, learning_rate=0.5, total=   0.1s
# [CV] subsample=0.8, n_estimators=900, min_child_weigh=6, max_depth=20, learning_rate=0.3
# [17:42:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.8, n_estimators=900, min_child_weigh=6, max_depth=20, learning_rate=0.3, total=   0.1s
# [CV] subsample=0.8, n_estimators=900, min_child_weigh=6, max_depth=20, learning_rate=0.3
# [17:42:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.8, n_estimators=900, min_child_weigh=6, max_depth=20, learning_rate=0.3, total=   0.1s
# [CV] subsample=0.8, n_estimators=900, min_child_weigh=6, max_depth=20, learning_rate=0.3
# [17:42:16] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV]  subsample=0.8, n_estimators=900, min_child_weigh=6, max_depth=20, learning_rate=0.3, total=   0.1s
# [CV] subsample=0.8, n_estimators=900, min_child_weigh=6, max_depth=20, learning_rate=0.3
# [17:42:16] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.8, n_estimators=900, min_child_weigh=6, max_depth=20, learning_rate=0.3, total=   0.1s
# [CV] subsample=0.8, n_estimators=900, min_child_weigh=6, max_depth=20, learning_rate=0.3
# [17:42:16] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.8, n_estimators=900, min_child_weigh=6, max_depth=20, learning_rate=0.3, total=   0.1s
# [CV] subsample=0.6, n_estimators=1100, min_child_weigh=7, max_depth=20, learning_rate=0.3
# [17:42:16] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=1100, min_child_weigh=7, max_depth=20, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.6, n_estimators=1100, min_child_weigh=7, max_depth=20, learning_rate=0.3
# [17:42:16] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=1100, min_child_weigh=7, max_depth=20, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.6, n_estimators=1100, min_child_weigh=7, max_depth=20, learning_rate=0.3
# [17:42:16] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=1100, min_child_weigh=7, max_depth=20, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.6, n_estimators=1100, min_child_weigh=7, max_depth=20, learning_rate=0.3
# [17:42:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=1100, min_child_weigh=7, max_depth=20, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.6, n_estimators=1100, min_child_weigh=7, max_depth=20, learning_rate=0.3
# [17:42:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=1100, min_child_weigh=7, max_depth=20, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.7, n_estimators=700, min_child_weigh=6, max_depth=5, learning_rate=0.2
# [17:42:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=700, min_child_weigh=6, max_depth=5, learning_rate=0.2, total=   0.2s
# [CV] subsample=0.7, n_estimators=700, min_child_weigh=6, max_depth=5, learning_rate=0.2
# [17:42:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=700, min_child_weigh=6, max_depth=5, learning_rate=0.2, total=   0.2s
# [CV] subsample=0.7, n_estimators=700, min_child_weigh=6, max_depth=5, learning_rate=0.2
# [17:42:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=700, min_child_weigh=6, max_depth=5, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.7, n_estimators=700, min_child_weigh=6, max_depth=5, learning_rate=0.2
# [17:42:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=700, min_child_weigh=6, max_depth=5, learning_rate=0.2, total=   0.2s
# [CV] subsample=0.7, n_estimators=700, min_child_weigh=6, max_depth=5, learning_rate=0.2
# [17:42:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=700, min_child_weigh=6, max_depth=5, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.7, n_estimators=900, min_child_weigh=7, max_depth=15, learning_rate=0.6
# [17:42:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=900, min_child_weigh=7, max_depth=15, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.7, n_estimators=900, min_child_weigh=7, max_depth=15, learning_rate=0.6
# [17:42:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=900, min_child_weigh=7, max_depth=15, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.7, n_estimators=900, min_child_weigh=7, max_depth=15, learning_rate=0.6
# [17:42:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV]  subsample=0.7, n_estimators=900, min_child_weigh=7, max_depth=15, learning_rate=0.6, total=   0.2s
# [CV] subsample=0.7, n_estimators=900, min_child_weigh=7, max_depth=15, learning_rate=0.6
# [17:42:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=900, min_child_weigh=7, max_depth=15, learning_rate=0.6, total=   0.2s
# [CV] subsample=0.7, n_estimators=900, min_child_weigh=7, max_depth=15, learning_rate=0.6
# [17:42:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.7, n_estimators=900, min_child_weigh=7, max_depth=15, learning_rate=0.6, total=   0.1s
# [CV] subsample=0.6, n_estimators=800, min_child_weigh=3, max_depth=25, learning_rate=0.05
# [17:42:19] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=800, min_child_weigh=3, max_depth=25, learning_rate=0.05, total=   0.4s
# [CV] subsample=0.6, n_estimators=800, min_child_weigh=3, max_depth=25, learning_rate=0.05
# [17:42:19] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=800, min_child_weigh=3, max_depth=25, learning_rate=0.05, total=   0.4s
# [CV] subsample=0.6, n_estimators=800, min_child_weigh=3, max_depth=25, learning_rate=0.05
# [17:42:19] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=800, min_child_weigh=3, max_depth=25, learning_rate=0.05, total=   0.5s
# [CV] subsample=0.6, n_estimators=800, min_child_weigh=3, max_depth=25, learning_rate=0.05
# [17:42:20] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=800, min_child_weigh=3, max_depth=25, learning_rate=0.05, total=   0.4s
# [CV] subsample=0.6, n_estimators=800, min_child_weigh=3, max_depth=25, learning_rate=0.05
# [17:42:20] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=800, min_child_weigh=3, max_depth=25, learning_rate=0.05, total=   0.5s
# [CV] subsample=0.8, n_estimators=900, min_child_weigh=5, max_depth=5, learning_rate=0.3
# [17:42:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.8, n_estimators=900, min_child_weigh=5, max_depth=5, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.8, n_estimators=900, min_child_weigh=5, max_depth=5, learning_rate=0.3
# [17:42:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.8, n_estimators=900, min_child_weigh=5, max_depth=5, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.8, n_estimators=900, min_child_weigh=5, max_depth=5, learning_rate=0.3
# [17:42:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.8, n_estimators=900, min_child_weigh=5, max_depth=5, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.8, n_estimators=900, min_child_weigh=5, max_depth=5, learning_rate=0.3
# [17:42:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.8, n_estimators=900, min_child_weigh=5, max_depth=5, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.8, n_estimators=900, min_child_weigh=5, max_depth=5, learning_rate=0.3
# [17:42:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.8, n_estimators=900, min_child_weigh=5, max_depth=5, learning_rate=0.3, total=   0.1s
# [CV] subsample=0.6, n_estimators=500, min_child_weigh=7, max_depth=15, learning_rate=0.1
# [17:42:22] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=500, min_child_weigh=7, max_depth=15, learning_rate=0.1, total=   0.2s
# [CV] subsample=0.6, n_estimators=500, min_child_weigh=7, max_depth=15, learning_rate=0.1
# [17:42:22] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV]  subsample=0.6, n_estimators=500, min_child_weigh=7, max_depth=15, learning_rate=0.1, total=   0.2s
# [CV] subsample=0.6, n_estimators=500, min_child_weigh=7, max_depth=15, learning_rate=0.1
# [17:42:22] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=500, min_child_weigh=7, max_depth=15, learning_rate=0.1, total=   0.2s
# [CV] subsample=0.6, n_estimators=500, min_child_weigh=7, max_depth=15, learning_rate=0.1
# [17:42:22] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=500, min_child_weigh=7, max_depth=15, learning_rate=0.1, total=   0.2s
# [CV] subsample=0.6, n_estimators=500, min_child_weigh=7, max_depth=15, learning_rate=0.1
# [17:42:22] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  subsample=0.6, n_estimators=500, min_child_weigh=7, max_depth=15, learning_rate=0.1, total=   0.2s
# [17:42:23] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { min_child_weigh } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    8.7s finished
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, gamma=None,
#                                           gpu_id=None, importance_type='gain',
#                                           interaction_constraints=None,
#                                           learning_rate=None,
#                                           max_delta_step=None, max_depth=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           n_estimators=100, n...
#                                           reg_lambda=None,
#                                           scale_pos_weight=None, subsample=None,
#                                           tree_method=None,
#                                           validate_parameters=None,
#                                           verbosity=None),
#                    n_jobs=1,
#                    param_distributions={'learning_rate': ['0.05', '0.1', '0.2',
#                                                           '0.3', '0.5', '0.6'],
#                                         'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'min_child_weigh': [3, 4, 5, 6, 7],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200],
#                                         'subsample': [0.7, 0.6, 0.8]},
#                    verbose=2)

# %%
# Finding the best parameter after performing hyperparameter tuning
random_search.best_params_
# Out:
# {'subsample': 0.7,
#  'n_estimators': 400,
#  'min_child_weigh': 5,
#  'max_depth': 20,
#  'learning_rate': '0.6'}

# %%
# Passing the best parameter to XGB Regressor for model building
xgb_reg = xgb.XGBRegressor(subsample=0.7, n_estimators=400, min_child_weight=5, max_depth=20, learning_rate="0.6", n_jobs=1, verbose=2)

# %%
# Fitting the model after hyperparameter optimization
xgb_reg.fit(X_train, y_train)
# Out:
# [17:42:46] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate='0.6', max_delta_step=0, max_depth=20,
#              min_child_weight=5, missing=nan, monotone_constraints='()',
#              n_estimators=400, n_jobs=1, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.7,
#              tree_method='exact', validate_parameters=1, verbose=2,
#              verbosity=None)

# %%
xgb_reg.predict(X_test)#----Prediction on testing set
# Out:
# array([ 4.2115126 ,  5.1915164 ,  7.421926  ,  8.232878  ,  2.7242868 ,
#         5.7825613 ,  2.918094  ,  3.1296747 ,  3.4802535 ,  7.1511173 ,
#         2.771962  ,  1.2655517 ,  5.9982066 ,  3.7234716 ,  1.6480467 ,
#        15.486972  , 27.27382   ,  4.635082  , 24.817537  ,  6.218576  ,
#        27.235065  ,  4.7757835 , 13.3938875 ,  5.9116898 ,  4.0753784 ,
#        27.27382   ,  5.9870706 , 22.30395   , 10.288624  ,  1.5570881 ,
#         1.3846631 ,  2.3887787 ,  1.0560584 ,  0.740522  ,  0.6136012 ,
#         0.66504157,  0.6095016 ,  0.54291636,  0.5776526 ,  0.12172472,
#         0.44773468, -2.490356  ,  0.3041421 ,  2.5920742 ,  4.670278  ,
#         2.3092103 ,  5.0043235 ,  4.7191415 ,  8.849977  ,  3.1477363 ,
#         4.6891317 ,  4.9620085 ,  5.1019535 ,  6.41009   ,  8.760101  ,
#        10.393255  ,  5.4037995 ,  2.6720183 ,  4.3280244 ,  7.4200306 ],
#       dtype=float32)

# %%
# Returning the R^2 Score of the prediction
xgb_reg.score(X_test, y_test)
# Out:
# 0.9407916675434569

# %%
# Importing pickel for saving the model
import pickle
model = open("Price_prediction_XGB_model.pkl", "wb")

# Dumping the information into the model
pickle.dump(xgb_reg, model)
